# %%
data={"a":10,
      "b":20,
      "c":50,
      "d":5,
    }

# %%
data={"a":10,
      "b":20,
      "c":50,
      "d":5,
    }
given=[22,10,97,17,5]
wanted=[]#
x=20
for i in range(0,5):
    if x< given[i]:
        pass
    else:
        temp=(given[i])
        wanted.append(temp)
print(wanted)
