# %% [markdown]
# # length of data

# %%
thislist=[3,4,5]
print(len(thislist))
# Out:
# 3

# %%
thislist=[2,4,6]
print(len(thislist))
# Out:
# 3

# %%
thisdict= {"a":10,"b":11} #when calculate u get the quanity members inside in this case the pairs
print(len(thisdict))
# Out:
# 2

# %%
name="isaac"            # 'a'-> char                        # 'Hello'->string
print(len(name))
# Out:
# 5

# %%
age="14"                # what was initilly wrong here was the quotations/brackets->before there was no quoatations around 14 so it wouldnt work
print(len(age))
# Out:
# 2

# %% [markdown]
# ## Markdown

# %%
#printed all the numbers less than 5
# Alex's notes: if condition is ture, then you execture the loop body
i=1
while i < 5:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
while i <= 10:
    print(i)
    i=i+1

sum=(i) # sum of all numbers added up to eachother
sum=sum+i
print(sum)
# Out:
#   Cell In[19], line 2
#     while i =< 10:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Sum Number 1-10

# %%
i = 1
sum=0
while i<=10:
    sum=sum+i
    i=i+1
print(sum)
# Out:
# 55

# %% [markdown]
# ## Find the Key

# %%
given=[22,10,97,17,5]
wanted=[]
    if x>given[i]<20:
        pass
# Out:
#   Cell In[1], line 3
#     if x>given[i]<20:
#     ^
# IndentationError: unexpected indent

# %%
#find the key in the value

data= {"a":10,
       "b":20,
       "c":50,
       "d":5,
        }
if i in (data):
    if (data)< 49:
        pass
    else:
        temp=(data)
for x in data.items():
    print(x)
# Out:
# ('a', 10)
# ('b', 20)
# ('c', 50)
# ('d', 5)

# %%
#find the key in the value

data= {"a":10, #define each data line
       "b":20,
       "c":50,
       "d":5,
        }
if i in (data):
    if (data)< 49:
        pass # Means "do nothing" if the condition is true
    else:
        temp=(data) #Stores the entire dictionary in a new variable called 'temp'
for x in data.items(): #Loops through each key-value pair in the dictionary
    print(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       1 #find the key in the value
#       3 data= {"a":10, #define each data line
#       4        "b":20,
#       5        "c":50,
#       6        "d":5,
#       7         }
# ----> 8 if i in (data):
#       9     if (data)< 49:
#      10         pass # Means "do nothing" if the condition is true
#
# NameError: name 'i' is not defined

# %%
i = 1
sum=0
while i<=49:
    sum=sum+i
    i=i+1
print(sum)
data= {"a":10,
       "b":20,
       "c":50,
       "d":5,
        }
for k,v in data.items():
    print(k,v)
# Out:
# 1225
# a 10
# b 20
# c 50
# d 5

# %%
data= {"a":10,
       "b":20,
       "c":50,
       "d":5,
        }
max=-1
for k,v in data.items():
    if v > max:
        max=v
    else:
        pass
print(max)
# Out:
# 50

# %%
data= {"a":10,
       "b":20,
       "c":50,
       "d":5,
        }
max=-1
for k,v in data.items():
    if v > max:
        max=v
        l_k=k # need new variable-> introduce new variable and the key's rely on the values in this case.
print (f"{l_k} {max}")
# Out:
# c 50
