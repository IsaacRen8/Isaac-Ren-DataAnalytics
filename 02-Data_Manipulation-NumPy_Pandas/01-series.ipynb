# %% [markdown]
# # Import

# %%
import numpy as np # numpy same as np
import pandas as pd # pandas same as pd

# %% [markdown]
# # What is series?

# %% [markdown]
# ## Theory is a single column datasheet plus index column

# %% [markdown]
# # Creating a series through a list

# %%
mydata=[1776,1867,1621] # mydata = list
myseries=pd.Series(data=mydata) #on the right hand of = side is important
                                #pd.Series=Pandasseries
                                #pd.Series(data=mydata) is pd's Series
                                #Series created from data
                                #MySeries series

myseries          
                                #dtype is short for data type
                                # int32 example of refrence range of integer(-100,100).  2^32=int32
                                # int64 example of refrence range of integer(-1000,1000). 2^64=int64
# Out:
# 0    1776
# 1    1867
# 2    1621
# dtype: int64

# %% [markdown]
# # Create series by customize index

# %%
myindex=['USA','Canada','Mexico']
myseries2= pd.Series (data = mydata, index = myindex)#adding names for the index/columm
myseries2
# Out:
# USA       1776
# Canada    1867
# Mexico    1621
# dtype: int64

# %% [markdown]
# # Create random number by using Numpy

# %%
rand_num=np.random.randint(0,100,4) #(start/minimun/range of #'s,end/maxiumum,quantity of numbers)
#random numbers bc of randit
rand_num
# Out:
# array([91, 56, 14, 17])

# %%
myindex=['Will','Isaac','Alex']
rand_num=np.random.randint(14,30,3)
myseries2 = pd.Series (data = rand_num,index = myindex)
myseries2
# Out:
# Will     28
# Isaac    29
# Alex     27
# dtype: int64
