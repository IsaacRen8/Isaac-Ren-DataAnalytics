# %%
# Definition=
# As long as more than one columns of an exel sheet, then it is called data sheet

# %% [markdown]
# ## Import

# %%
import numpy as np # numpy same as np
import pandas as pd # pandas same as pd

# %% [markdown]
# # Creating a Dataframe

# %%
mydata = np.random.randint(0,101,(4,3))#4x3||4 is row 3 is column
my_index = ['CA','NY','AZ','TX']
my_col = ['Jan','Feb','Mar'] # col is column for short
df=pd.DataFrame(data=mydata,index=my_index,columns=my_col)#df is dataframe
df
# Out:
#     Jan  Feb  Mar
# CA   87   64   96
# NY   66   53   76
# AZ   37   55   97
# TX   24   22   94

# %% [markdown]
# # Read .csv file

# %%
df = pd.read_csv('tips.csv')
df
# a smart display system that displays the first 5 and last 5 lines as some 
# files can have millions and could be way to long
# FOR COLUMNS there are 11 different features/data including the column is 12
# FOR ROWS not including title row is 244
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ### Assingment 1. import read .csv file(basketball file) 2. Explain a details of features everysingle one. 3. Comepeup with an idea of a description of the dataset(objective truth no sujective truth) 4. According to the basketball datasets... Propose a study on at least 2 topics you can research

# %%
# Read the NBA .csv File

# %%
# Explain the details of the features

## There are 25 head columns
# Column Descriptions
# Player: Name of the player.
#Tm: Abbreviation of the player's team.
#Opp: Abbreviation of the opposing team.
#Res: Result of the game for the player's team.
#MP: Minutes played, represented as a float (e.g., 23.5 = 23 minutes and 30 seconds).
#FG: Field goals made.
#FGA: Field goal attempts.
#FG%: Field goal percentage.
#3P: 3-point field goals made.
#3PA: 3-point field goal attempts.
#3P%: 3-point shooting percentage.
#FT: Free throws made.
#FTA: Free throw attempts.
#FT%: Free throw percentage.
#ORB: Offensive rebounds.
#DRB: Defensive rebounds.
#TRB: Total rebounds.
#AST: Assists.
#3STL: Steals.
#BLK: Blocks.
#TOV: Turnovers.
#PF: Personal fouls.
#PTS: Total points scored.
#GmSc: Game Score, a metric summarizing player performance for the game.
#Data: Date of the game in YYYY-MM-DD format.

# %%
# Write the description of the dataset (Objective truth)

# The dataset includes detailed performance stats for NBA players from the 2024–2025
# season. It covers both basic stats (like points and rebounds) and advanced
# metrics (such as efficiency ratings), making it perfect for analyzing how players
# are performing, comparing their stats, and spotting trends over the season.
# The data is on Every single player in the NBA during the 24-25 season.
# It’s good for looking into player performance analysis,
# track trends, or predict future outcomes.

# %%
# According to the study of our dataset, propose at least two topics that I can
#  research through our dataset.

#/// 1. First topic: The impact of minutes played on player efficentcy. So
# If one player has a great game say 30 pts and a triple double. How does that affect
# the next game they will play? Will they perform the same or perform significantly
# worse due to fatigue and how does that affect the teams win and loss count

#// Second topic:  Shooting efficentcy vs. Shot Volume
# This topic looks at whether players who take more shots still make them 
# at a high rate. It lools if shooting a lot makes a player less accurate, 
# or if some players can keep scoring well even with more attempts.

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Obtaining Basic Information About DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)#this will print the first numbers. On default without any numbers
#e.g.(3) it will print the first 5
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
len(df)  # This gives the number of rows
# Out:
# 244

# %%
len(df.columns) # This prints the number of columns
# Out:
# 11

# %% [markdown]
# # Selction and Indexing

# %%
# Grab a single column

# %% [markdown]
# ### Grab a single column

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
df['total_bill'].head(9) # combines the two together
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# 5    25.29
# 6     8.77
# 7    26.88
# 8    15.04
# Name: total_bill, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Grab Multiple Columns

# %%
# Note how its a python list of column names!  Thus the double brackets.
df[['total_bill','tip','sex']]
# Out:
#      total_bill   tip     sex
# 0         16.99  1.01  Female
# 1         10.34  1.66    Male
# 2         21.01  3.50    Male
# 3         23.68  3.31    Male
# 4         24.59  3.61  Female
# ..          ...   ...     ...
# 239       29.03  5.92    Male
# 240       27.18  2.00  Female
# 241       22.67  2.00    Male
# 242       17.82  1.75    Male
# 243       18.78  3.00  Female
#
# [244 rows x 3 columns]

# %% [markdown]
# # Creating a New Feature

# %%
df['tip_percentage'] = 100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959             100
# 1      Douglas Tucker  4478071379779230    Sun4608             100
# 2      Travis Walters  6011812112971322    Sun4458             100
# 3    Nathaniel Harris  4676137647685994    Sun5260             100
# 4        Tonya Carter  4832732618637221    Sun2251             100

# %% [markdown]
# ##

# %%
df['tip_percentage'] = 100* df['tip'] / df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %% [markdown]
# ## Adjust Existing Column

# %%
df['price_per_person'] = np.round(df['price_per_person'],1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
# df.drop('tip_percentage',axis=1)

# %%
df = df.drop("tip_percentage",axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Set Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.5  Christy Cunningham  3560325168603410
# ...

# %% [markdown]
# # Reset Index

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0               8.5  Christy Cunningham  3560325168603410    Sun2959
# 1               3.4      Douglas Tucker  4478071379779230    Sun4608
# 2               7.0      Travis Walters  6011812112971322    Sun4458
# 3              11.8    Nathaniel Harris  4676137647685994    Sun5260
# 4               6.2        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Grab a Single Row

# %%
# Integer Based
df.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.5
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 0, dtype: object

# %% [markdown]
# # Grab Multiple Rows

# %%
df.iloc[0:4]
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0               8.5  Christy Cunningham  3560325168603410    Sun2959
# 1               3.4      Douglas Tucker  4478071379779230    Sun4608
# 2               7.0      Travis Walters  6011812112971322    Sun4458
# 3              11.8    Nathaniel Harris  4676137647685994    Sun5260

# %% [markdown]
# # Remove a Row

# %%
df.drop('Sun2959', axis=)
# Out:
#   Cell In[72], line 1
#     df.drop('Sun2959', axis=)
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Conditional Filter

# %% [markdown]
# ## Single Condition

# %%
bool_series = df['tip'] > 5
bool_series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
df[bool_series]
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 44      44       30.40   5.60    Male     No   Sun  Dinner     4
# 47      47       32.40   6.00    Male     No   Sun  Dinner     4
# 52      52       34.81   5.20  Female     No   Sun  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 85      85       34.83   5.17  Female     No  Thur   Lunch     4
# 88      88       24.71   5.85    Male     No  Thur   Lunch     2
# 116    116       29.93   5.07    Male     No   Sun  Dinner     4
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 155    155       29.85   5.14  Female     No   Sun  Dinner     5
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172    172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181    181       23.33   5.65    Male    Yes   Sun  Dinner     2
# ...

# %%
df[df['tip'] > 5]
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 44      44       30.40   5.60    Male     No   Sun  Dinner     4
# 47      47       32.40   6.00    Male     No   Sun  Dinner     4
# 52      52       34.81   5.20  Female     No   Sun  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 85      85       34.83   5.17  Female     No  Thur   Lunch     4
# 88      88       24.71   5.85    Male     No  Thur   Lunch     2
# 116    116       29.93   5.07    Male     No   Sun  Dinner     4
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 155    155       29.85   5.14  Female     No   Sun  Dinner     5
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172    172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181    181       23.33   5.65    Male    Yes   Sun  Dinner     2
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#      index  total_bill   tip   sex smoker  day    time  size  \
# 1        1       10.34  1.66  Male     No  Sun  Dinner     3
# 2        2       21.01  3.50  Male     No  Sun  Dinner     3
# 3        3       23.68  3.31  Male     No  Sun  Dinner     2
# 5        5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        6        8.77  2.00  Male     No  Sun  Dinner     2
# ..     ...         ...   ...   ...    ...  ...     ...   ...
# 236    236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237    237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239    239       29.03  5.92  Male     No  Sat  Dinner     3
# 241    241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75  Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 1                 3.4      Douglas Tucker  4478071379779230    Sun4608
# 2                 7.0      Travis Walters  6011812112971322    Sun4458
# ...

# %% [markdown]
# # Multiple-Condition

# %%
df[(df['total_bill'] > 30) & (df["sex"]=='Male')]
# Out:
#      index  total_bill    tip   sex smoker   day    time  size  \
# 23      23       39.42   7.58  Male     No   Sat  Dinner     4
# 39      39       31.27   5.00  Male     No   Sat  Dinner     3
# 44      44       30.40   5.60  Male     No   Sun  Dinner     4
# 47      47       32.40   6.00  Male     No   Sun  Dinner     4
# 56      56       38.01   3.00  Male    Yes   Sat  Dinner     4
# 59      59       48.27   6.73  Male     No   Sat  Dinner     4
# 83      83       32.68   5.00  Male    Yes  Thur   Lunch     2
# 95      95       40.17   4.73  Male    Yes   Fri  Dinner     4
# 112    112       38.07   4.00  Male     No   Sun  Dinner     3
# 141    141       34.30   6.70  Male     No  Thur   Lunch     6
# 142    142       41.19   5.00  Male     No  Thur   Lunch     5
# 156    156       48.17   5.00  Male     No   Sun  Dinner     6
# 167    167       31.71   4.50  Male     No   Sun  Dinner     4
# 170    170       50.81  10.00  Male    Yes   Sat  Dinner     3
# ...

# %%
df[(df['day']=='Sun') | (df['day']=='Sat')]
# Out:
#      index  total_bill   tip     sex smoker  day    time  size  \
# 0        0       16.99  1.01  Female     No  Sun  Dinner     2
# 1        1       10.34  1.66    Male     No  Sun  Dinner     3
# 2        2       21.01  3.50    Male     No  Sun  Dinner     3
# 3        3       23.68  3.31    Male     No  Sun  Dinner     2
# 4        4       24.59  3.61  Female     No  Sun  Dinner     4
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 238    238       35.83  4.67  Female     No  Sat  Dinner     3
# 239    239       29.03  5.92    Male     No  Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                 8.5  Christy Cunningham  3560325168603410    Sun2959
# ...
